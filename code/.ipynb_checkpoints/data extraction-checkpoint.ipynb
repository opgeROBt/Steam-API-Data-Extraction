# %%
#import libraries needed for this proces
import requests
from datetime import datetime
import numpy
import time
import json
import pandas as pd
import sys

# %%
#function to create an API request based on URL and  parameters
def get_request(url, parameters=None):
    print("Your request is being processed.")
    response = requests.get(url=url, params=parameters)
    if response:
        return response.json()
        
    else:
        print("Request unsuccessful, retrying in 5 seconds.")
        time.sleep(5)
        return get_request(url, parameters)
    time.sleep(1)

# %%
#using the function to get all data id's which include appid and app name 
url = "https://api.steampowered.com/ISteamApps/GetAppList/v2/"
parameters = {"request": all}
data_ids = get_request(url, parameters=parameters)
print("Your request has been processed successfully, call upon 'data_ids' to preview the full list of IDs and names of all currently available products on Steam as of ", datetime.now().strftime("%d/%m/%Y %H:%M:%S"), ".")
# Out:
# Your request is being processed.
# Your request has been processed successfully, call upon 'data_ids' to preview the full list of IDs and names of all currently available products on Steam as of  16/03/2022 16:07:41 .

# %%
#Code to collect all app id's in one library
app_ids = []
print("Creating a list of all IDs currently available on Steam")
for item in data_ids['applist']['apps']:
    app_ids.append(item['appid'])

print("List created sucessfully, the total number of IDs available on Steam is:", len(app_ids),".")
print("Call upon 'app_ids' to preview the full list of extracted IDs.")
# Out:
# Creating a list of all IDs currently available on Steam
# List created sucessfully, the total number of IDs available on Steam is: 138225 .
# Call upon 'app_ids' to preview the full list of extracted IDs.
# [216938,
#  660010,
#  660130,
#  1118314,
#  1275822,
#  1343832,
#  1828741,
#  662172,
#  1360782,
#  1820332,
#  1815690,
#  1815720,
#  1815730,
#  1815740,
#  1815750,
#  1815770,
#  1815800,
#  1815820,
#  1815860,
#  1815870,
#  1815880,
#  1815890,
#  1815931,
#  1815932,
#  1815933,
#  1815950,
#  1815970,
#  1815990,
#  1816010,
#  1816020,
#  1816050,
#  1816060,
#  1816080,
#  1816100,
#  1816120,
#  1816130,
#  1815250,
#  1815260,
#  1815270,
#  1815300,
#  1815310,
#  1815340,
#  1815350,
#  1815370,
#  1815400,
#  1815430,
#  1815440,
#  1815450,
#  1815470,
#  1815490,
#  1815500,
#  1815550,
#  1815580,
#  1815590,
#  1815600,
#  1815610,
#  1815620,
#  1815650,
#  1815660,
#  1814730,
#  1814740,
#  1814750,
#  1814760,
#  1814770,
#  1814780,
#  1814800,
#  1814840,
#  1814850,
#  1814860,
#  1814870,
#  1814880,
#  1814920,
#  1814930,
#  1814940,
#  1814950,
#  1814960,
#  1814970,
#  1814990,
#  1815000,
#  1815010,
#  1815020,
#  1815030,
#  1815040,
#  1815050,
#  1815060,
#  1815080,
#  1815090,
#  1815110,
#  1815130,
#  1815140,
#  1815160,
#  1815170,
#  1815190,
#  1815200,
#  1815210,
#  1814220,
#  1814230,
#  1814240,
#  1814250,
#  1814260,
#  1814270,
#  1814300,
#  1814310,
#  1814340,
#  1814370,
#  1814380,
#  1814390,
#  1814400,
#  1814430,
#  1814450,
#  1814480,
#  1814490,
#  1814500,
#  1814510,
#  1814520,
#  1814540,
#  1814550,
#  1814560,
#  1814570,
#  1814590,
#  1814600,
#  1814610,
#  1814630,
#  1814640,
#  1814650,
#  1814660,
#  1814670,
#  1814680,
#  1814690,
#  1814700,
#  1814710,
#  1813740,
#  1813750,
#  1813780,
#  1813790,
#  1813810,
#  1813820,
#  1813830,
#  1813840,
#  1813850,
#  1813860,
#  1813880,
#  1813890,
#  1813930,
#  1813940,
#  1813960,
#  1813990,
#  1814000,
#  1814010,
#  1814030,
#  1814040,
#  1814060,
#  1814090,
#  1814100,
#  1814110,
#  1814120,
#  1814150,
#  1814160,
#  1814170,
#  1814180,
#  1814200,
#  1814210,
#  1813230,
#  1813240,
#  1813260,
#  1813300,
#  1813310,
#  1813320,
#  1813330,
#  1813340,
#  1813350,
#  1813360,
#  1813370,
#  1813390,
#  1813400,
#  1813410,
#  1813450,
#  1813460,
#  1813480,
#  1813510,
#  1813520,
#  1813540,
#  1813550,
#  1813560,
#  1813570,
#  1813590,
#  1813620,
#  1813650,
#  1813670,
#  1813690,
#  1813710,
#  1812820,
#  1812840,
#  1812850,
#  1812860,
#  1812870,
#  1812880,
#  1812881,
#  1812882,
#  1812883,
#  1812884,
#  1812885,
#  1812886,
#  1812887,
#  1812888,
#  1812889,
#  1812890,
#  1812920,
#  1812940,
#  1812950,
#  1812960,
#  1812970,
#  1812980,
#  1813000,
#  1813010,
#  1813040,
#  1813050,
#  1813060,
#  1813070,
#  1813080,
#  1813090,
#  1813100,
#  1813110,
#  1813140,
#  1813150,
#  1813160,
#  1813170,
#  1813180,
#  1813190,
#  1813200,
#  1813210,
#  1812400,
#  1812430,
#  1812440,
#  1812470,
#  1812480,
#  1812481,
#  1812482,
#  1812483,
#  1812484,
#  1812485,
#  1812486,
#  1812487,
#  1812490,
#  1812520,
#  1812530,
#  1812540,
#  1812550,
#  1812580,
#  1812600,
#  1812630,
#  1812640,
#  1812650,
#  1812710,
#  1812720,
#  1812750,
#  1812760,
#  1812770,
#  1812780,
#  1811900,
#  1811910,
#  1811920,
#  1811930,
#  1811940,
#  1812000,
#  1812060,
#  1812070,
#  1812080,
#  1812100,
#  1812110,
#  1812130,
#  1812140,
#  1812150,
#  1812151,
#  1812152,
#  1812153,
#  1812160,
#  1812190,
#  1812200,
#  1812250,
#  1812260,
#  1812270,
#  1812280,
#  1812310,
#  1812320,
#  1812330,
#  1812340,
#  1812350,
#  1812360,
#  1811400,
#  1811410,
#  1811420,
#  1811450,
#  1811460,
#  1811480,
#  1811490,
#  1811520,
#  1811530,
#  1811550,
#  1811570,
#  1811580,
#  1811590,
#  1811600,
#  1811620,
#  1811630,
#  1811640,
#  1811650,
#  1811690,
#  1811700,
#  1811710,
#  1811740,
#  1811750,
#  1811770,
#  1811780,
#  1811790,
#  1811800,
#  1811820,
#  1811830,
#  1811840,
#  1811850,
#  1811860,
#  1811870,
#  1811890,
#  1810940,
#  1810960,
#  1810990,
#  1810991,
#  1810992,
#  1810993,
#  1811020,
#  1811030,
#  1811050,
#  1811060,
#  1811070,
#  1811080,
#  1811090,
#  1811100,
#  1811101,
#  1811110,
#  1811120,
#  1811140,
#  1811150,
#  1811160,
#  1811180,
#  1811210,
#  1811220,
#  1811230,
#  1811250,
#  1811280,
#  1811290,
#  1811300,
#  1811330,
#  1811350,
#  1811390,
#  1810490,
#  1810500,
#  1810510,
#  1810530,
#  1810560,
#  1810561,
#  1810562,
#  1810563,
#  1810580,
#  1810590,
#  1810600,
#  1810610,
#  1810620,
#  1810640,
#  1810650,
#  1810670,
#  1810690,
#  1810700,
#  1810710,
#  1810720,
#  1810770,
#  1810780,
#  1810800,
#  1810810,
#  1810840,
#  1810870,
#  1810880,
#  1810900,
#  1810910,
#  1810920,
#  1809960,
#  1809990,
#  1810000,
#  1810010,
#  1810020,
#  1810030,
#  1810031,
#  1810090,
#  1810100,
#  1810110,
#  1810130,
#  1810170,
#  1810180,
#  1810200,
#  1810210,
#  1810220,
#  1810230,
#  1810240,
#  1810270,
#  1810280,
#  1810290,
#  1810310,
#  1810320,
#  1810330,
#  1810350,
#  1810360,
#  1810370,
#  1810400,
#  1810410,
#  1810420,
#  1810430,
#  1809463,
#  1809530,
#  1809560,
#  1809570,
#  1809600,
#  1809610,
#  1809650,
#  1809660,
#  1809670,
#  1809690,
#  1809710,
#  1809730,
#  1809740,
#  1809750,
#  1809760,
#  1809770,
#  1809790,
#  1809800,
#  1809810,
#  1809820,
#  1809830,
#  1809850,
#  1809860,
#  1809890,
#  1809900,
#  1809930,
#  1809940,
#  1809110,
#  1809120,
#  1809121,
#  1809122,
#  1809123,
#  1809124,
#  1809125,
#  1809126,
#  1809127,
#  1809128,
#  1809130,
#  1809140,
#  1809150,
#  1809160,
#  1809170,
#  1809200,
#  1809210,
#  1809230,
#  1809250,
#  1809280,
#  1809290,
#  1809300,
#  1809330,
#  1809350,
#  1809360,
#  1809370,
#  1809400,
#  1809410,
#  1809411,
#  1809412,
#  1809413,
#  1809414,
#  1809420,
#  1809430,
#  1809460,
#  1809461,
#  1809462,
#  1808630,
#  1808670,
#  1808680,
#  1808690,
#  1808700,
#  1808710,
#  1808750,
#  1808800,
#  1808810,
#  1808820,
#  1808830,
#  1808840,
#  1808860,
#  1808870,
#  1808880,
#  1808890,
#  1808900,
#  1808910,
#  1808920,
#  1808930,
#  1808950,
#  1808960,
#  1808970,
#  1808980,
#  1808990,
#  1809030,
#  1809040,
#  1809070,
#  1809080,
#  1809090,
#  1808180,
#  1808200,
#  1808230,
#  1808240,
#  1808260,
#  1808270,
#  1808290,
#  1808320,
#  1808350,
#  1808360,
#  1808370,
#  1808380,
#  1808390,
#  1808400,
#  1808420,
#  1808430,
#  1808431,
#  1808440,
#  1808460,
#  1808480,
#  1808490,
#  1808500,
#  1808540,
#  1808550,
#  1808570,
#  1808580,
#  1807730,
#  1807740,
#  1807750,
#  1807780,
#  1807790,
#  1807800,
#  1807810,
#  1807840,
#  1807880,
#  1807920,
#  1807930,
#  1807940,
#  1807950,
#  1807980,
#  1808040,
#  1808050,
#  1808060,
#  1808070,
#  1808080,
#  1808090,
#  1808110,
#  1808120,
#  1808130,
#  1808140,
#  1808160,
#  1807280,
#  1807300,
#  1807310,
#  1807320,
#  1807370,
#  1807390,
#  1807400,
#  1807410,
#  1807420,
#  1807440,
#  1807450,
#  1807460,
#  1807480,
#  1807500,
#  1807510,
#  1807511,
#  1807512,
#  1807513,
#  1807514,
#  1807515,
#  1807520,
#  1807521,
#  1807522,
#  1807523,
#  1807524,
#  1807525,
#  1807526,
#  1807540,
#  1807550,
#  1807560,
#  1807570,
#  1807580,
#  1807590,
#  1807600,
#  1807610,
#  1807620,
#  1807640,
#  1807660,
#  1806790,
#  1806830,
#  1806840,
#  1806860,
#  1806870,
#  1806890,
#  1806900,
#  1806920,
#  1806940,
#  1806960,
#  1806970,
#  1806990,
#  1807000,
#  1807010,
#  1807020,
#  1807030,
#  1807040,
#  1807050,
#  1807060,
#  1807080,
#  1807090,
#  1807110,
#  1807130,
#  1807140,
#  1807150,
#  1807160,
#  1807170,
#  1807180,
#  1807200,
#  1807210,
#  1807220,
#  1807240,
#  1807250,
#  1807260,
#  1806280,
#  1806300,
#  1806340,
#  1806350,
#  1806380,
#  1806400,
#  1806410,
#  1806420,
#  1806430,
#  1806440,
#  1806460,
#  1806480,
#  1806500,
#  1806550,
#  1806570,
#  1806580,
#  1806610,
#  1806640,
#  1806660,
#  1806670,
#  1806690,
#  1806720,
#  1805960,
#  1805970,
#  1805980,
#  1806000,
#  1806030,
#  1806040,
#  1806060,
#  1806070,
#  1806090,
#  1806110,
#  1806120,
#  1806130,
#  1806140,
#  1806141,
#  1806142,
#  1806143,
#  1806144,
#  1806145,
#  1806146,
#  1806147,
#  1806148,
#  1806149,
#  1806150,
#  1806151,
#  1806152,
#  1806153,
#  1806154,
#  1806155,
#  1806156,
#  1806157,
#  1806158,
#  1806159,
#  1806170,
#  1806180,
#  1806190,
#  1806200,
#  1806260,
#  1805460,
#  1805470,
#  1805541,
#  1805550,
#  1805560,
#  1805570,
#  1805590,
#  1805600,
#  1805610,
#  1805640,
#  1805650,
#  1805670,
#  1805680,
#  1805720,
#  1805730,
#  1805740,
#  1805750,
#  1805770,
#  1805780,
#  1805790,
#  1805810,
#  1805820,
#  1805830,
#  1805850,
#  1805860,
#  1805870,
#  1805880,
#  1805890,
#  1805900,
#  1805920,
#  1805930,
#  1805051,
#  1805052,
#  1805070,
#  1805080,
#  1805100,
#  1805110,
#  1805130,
#  1805140,
#  1805150,
#  1805170,
#  1805180,
#  1805190,
#  1805200,
#  1805210,
#  1805220,
#  1805230,
#  1805250,
#  1805260,
#  1805270,
#  1805290,
#  1805310,
#  1805330,
#  1805340,
#  1805350,
#  1805390,
#  1805400,
#  1805420,
#  1805430,
#  1805440,
#  1805450,
#  1804650,
#  1804660,
#  1804670,
#  1804680,
#  1804690,
#  1804700,
#  1804730,
#  1804740,
#  1804760,
#  1804780,
#  1804790,
#  1804800,
#  1804820,
#  1804830,
#  1804840,
#  1804841,
#  1804842,
#  1804860,
#  1804870,
#  1804880,
#  1804890,
#  1804900,
#  1804950,
#  1804970,
#  1804980,
#  1804990,
#  1805000,
#  1805010,
#  1805020,
#  1805040,
#  1805050,
#  1804280,
#  1804290,
#  1804300,
#  1804320,
#  1804340,
#  1804360,
#  1804370,
#  1804380,
#  1804390,
#  1804420,
#  1804440,
#  1804450,
#  1804460,
#  1804470,
#  1804500,
#  1804510,
#  1804511,
#  1804512,
#  1804513,
#  1804514,
#  1804515,
#  1804520,
#  1804530,
#  1804560,
#  1804570,
#  1804580,
#  1804590,
#  1804600,
#  1804610,
#  1804620,
#  1804630,
#  1803790,
#  1803800,
#  1803820,
#  1803840,
#  1803870,
#  1803920,
#  1803940,
#  1803950,
#  1804010,
#  1804020,
#  1804030,
#  1804070,
#  1804090,
#  1804130,
#  1804140,
#  1804160,
#  1804170,
#  1804180,
#  1804200,
#  1804210,
#  1804220,
#  1803320,
#  1803340,
#  1803380,
#  1803390,
#  1803400,
#  1803420,
#  1803440,
#  1803450,
#  1803460,
#  1803470,
#  1803490,
#  1803500,
#  1803510,
#  1803520,
#  1803530,
#  1803550,
#  1803560,
#  1803570,
#  1803580,
#  1803590,
#  1803600,
#  1803620,
#  1803630,
#  1803640,
#  1803670,
#  1803680,
#  1803690,
#  1803700,
#  1803720,
#  1803730,
#  1803740,
#  1803742,
#  1803750,
#  1803760,
#  1802860,
#  1802870,
#  1802900,
#  1802920,
#  1802930,
#  1802950,
#  1802960,
#  1802970,
#  1803000,
#  1803020,
#  1803050,
#  1803060,
#  1803070,
#  1803090,
#  1803100,
#  1803120,
#  1803140,
#  1803150,
#  1803160,
#  1803170,
#  1803180,
#  1803190,
#  1803210,
#  1803220,
#  1803230,
#  1803240,
#  1803250,
#  1803260,
#  1803270,
#  1803280,
#  1803290,
#  1802380,
#  1802390,
#  1802400,
#  1802410,
#  1802430,
#  1802450,
#  1802451,
#  1802452,
#  1802460,
#  1802480,
#  1802490,
#  1802500,
#  1802520,
#  1802530,
#  1802540,
#  1802550,
#  1802560,
#  1802570,
#  1802590,
#  1802610,
#  1802620,
#  1802630,
#  1802660,
#  1802670,
#  1802700,
#  1802740,
#  1802760,
#  1802770,
#  1802810,
#  1802820,
#  1801890,
#  1801900,
#  1801910,
#  1801920,
#  1801930,
#  1801940,
#  1801950,
#  1801960,
#  1801970,
#  1801980,
#  1802030,
#  1802070,
#  1802080,
#  1802090,
#  1802100,
#  1802110,
#  1802120,
#  1802140,
#  1802150,
#  1802160,
#  1802180,
#  1802190,
#  1802210,
#  1802240,
#  1802260,
#  1802310,
#  1802320,
#  1802340,
#  1801775,
#  1801776,
#  1801777,
#  1801778,
#  1801779,
#  1801780,
#  1801781,
#  1801782,
#  1801783,
#  1801784,
#  1801785,
#  1801786,
#  1801787,
#  1801788,
#  1801789,
#  1801790,
#  1801791,
#  1801792,
#  1801793,
#  1801794,
#  1801795,
#  1801796,
#  1801797,
#  1801798,
#  1801799,
#  1801800,
#  1801801,
#  1801802,
#  1801803,
#  1801804,
#  1801805,
#  1801806,
#  1801807,
#  1801808,
#  1801809,
#  1801810,
#  1801811,
#  1801812,
#  1801813,
#  1801814,
#  1801815,
#  1801816,
#  ...]

# %%
# example code that collects the details of 1 app by appid  
url = "http://store.steampowered.com/api/appdetails/"
parameters = {"appids": "1815720"}
app_data = get_request(url, parameters=parameters)
app_data["1815720"]['data']
# Out:
# Your request is being processed.
# {'type': 'game',
#  'name': 'Split Tactics',
#  'steam_appid': 1815720,
#  'required_age': 0,
#  'is_free': False,
#  'detailed_description': 'Split Tactics is a casual game about choices. There are a total of 13 elements in this game. The 6 basic elements are: Fire, Ice, Poison, Dark, Light and Curse. Then there are 7 more that are their combinations: Chaos (Fire+Dark), Reflection (Ice+Light), Toxic Mist (Poison+Dark), Madness (Dark+Curse), Fume Gas (Fire+Poison), Horror Breath (Ice+Dark) and Divine Flame (Light+Fire). Each element basic or not, has its own effects when applied to an enemy. Players should choose spells based on effectiveness to creatures and also to avoid making opponent the next most powerful mage. A good strategic balance is required to overcome opponent and also stay alive for the duration of the game.<h2 class="bb_tag">Start of the Game</h2>Each player draws 5 cards from the reward card pile. The first enemy or trap is opened from the explore card pile. <br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/InitHand.png?t=1640856346" /><h2 class="bb_tag">Raw Attacks</h2>A player can choose to attack based on raw power (their level on the top right corner of the screen) to any explored enemy<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/RawAttack.png?t=1640856346" /><h2 class="bb_tag">Elemental Attacks</h2>Not so direct and powerful as the raw attacks. However, elemental attacks are your silent power, with tricks and effects that<br>apply over time or add up to the total damage as well as effects that control enemies or make them extremely vulnerable.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/ElementalAttack.png?t=1640856346" /><h2 class="bb_tag">Recycling Cards</h2>A player has the choice to recycle 2 cards from their hand for a new one. Doing so player also gains 3 life points. This is very<br>effective when working against your opponent, discarding valuable cards for them or in search of a better alternative for your plays.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/Recycling.png?t=1640856346" /><h2 class="bb_tag">Equipments</h2>A card from the reward pile can either be cast or used as an equipment. An exception to this rule are the crystal cards. Equipping<br>cards can make a difference as the elemental attacks become stronger. When equipping a card player also draws from the reward pile<br>a new card of the same element type, enabling more combos.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/Equipping.png?t=1640856346" /><h2 class="bb_tag">Casting Crystals</h2>A crystal can also be cast. This can be used for immediate effects as a crystal offers the choice of an AOE attacks that can destroy<br>remaining enemies and allow for quick loot or add up to the total damage.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/CastCrystals.png?t=1640856346" /><h2 class="bb_tag">Casting Powerful Spells</h2>For each element type there is a special spell that deals a huge amount of damage enemies (such as an explosion) or has a very drastic result to the gameplay.<br>Each of these spells are accompanied with a Visual Effect to showcase the impact.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/CastVFX.png?t=1640856346" /><h2 class="bb_tag">Restrictions</h2> Every player can only cast or equip up to 1 card from their hand each turn. Crystals can be cast or used as an equipment in addition to that number but only 1 per turn.<h2 class="bb_tag">Win/Lose Condition</h2>A player wins if they reach level 25 or if the opponent had their life points become 0.',
#  'about_the_game': 'Split Tactics is a casual game about choices. There are a total of 13 elements in this game. The 6 basic elements are: Fire, Ice, Poison, Dark, Light and Curse. Then there are 7 more that are their combinations: Chaos (Fire+Dark), Reflection (Ice+Light), Toxic Mist (Poison+Dark), Madness (Dark+Curse), Fume Gas (Fire+Poison), Horror Breath (Ice+Dark) and Divine Flame (Light+Fire). Each element basic or not, has its own effects when applied to an enemy. Players should choose spells based on effectiveness to creatures and also to avoid making opponent the next most powerful mage. A good strategic balance is required to overcome opponent and also stay alive for the duration of the game.<h2 class="bb_tag">Start of the Game</h2>Each player draws 5 cards from the reward card pile. The first enemy or trap is opened from the explore card pile. <br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/InitHand.png?t=1640856346" /><h2 class="bb_tag">Raw Attacks</h2>A player can choose to attack based on raw power (their level on the top right corner of the screen) to any explored enemy<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/RawAttack.png?t=1640856346" /><h2 class="bb_tag">Elemental Attacks</h2>Not so direct and powerful as the raw attacks. However, elemental attacks are your silent power, with tricks and effects that<br>apply over time or add up to the total damage as well as effects that control enemies or make them extremely vulnerable.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/ElementalAttack.png?t=1640856346" /><h2 class="bb_tag">Recycling Cards</h2>A player has the choice to recycle 2 cards from their hand for a new one. Doing so player also gains 3 life points. This is very<br>effective when working against your opponent, discarding valuable cards for them or in search of a better alternative for your plays.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/Recycling.png?t=1640856346" /><h2 class="bb_tag">Equipments</h2>A card from the reward pile can either be cast or used as an equipment. An exception to this rule are the crystal cards. Equipping<br>cards can make a difference as the elemental attacks become stronger. When equipping a card player also draws from the reward pile<br>a new card of the same element type, enabling more combos.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/Equipping.png?t=1640856346" /><h2 class="bb_tag">Casting Crystals</h2>A crystal can also be cast. This can be used for immediate effects as a crystal offers the choice of an AOE attacks that can destroy<br>remaining enemies and allow for quick loot or add up to the total damage.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/CastCrystals.png?t=1640856346" /><h2 class="bb_tag">Casting Powerful Spells</h2>For each element type there is a special spell that deals a huge amount of damage enemies (such as an explosion) or has a very drastic result to the gameplay.<br>Each of these spells are accompanied with a Visual Effect to showcase the impact.<br><br><img src="https://cdn.akamai.steamstatic.com/steam/apps/1815720/extras/CastVFX.png?t=1640856346" /><h2 class="bb_tag">Restrictions</h2> Every player can only cast or equip up to 1 card from their hand each turn. Crystals can be cast or used as an equipment in addition to that number but only 1 per turn.<h2 class="bb_tag">Win/Lose Condition</h2>A player wins if they reach level 25 or if the opponent had their life points become 0.',
#  'short_description': 'A turn-based LAN multiplayer card game where players share the same hand. Each player must make their own decisions on how to split the cards so that they leave less options to opponent and get closer to victory!',
#  'supported_languages': 'English',
#  'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/header.jpg?t=1640856346',
#  'website': None,
#  'pc_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Windows 7<br></li><li><strong>Processor:</strong> Intel Core i3 2.00 GHz or AMD equivalent<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia GeForce 950GTX or higher<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Network:</strong> Broadband Internet connection<br></li><li><strong>Storage:</strong> 300 MB available space</li></ul>',
#   'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>'},
#  'mac_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>',
#   'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>'},
#  'linux_requirements': {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>',
#   'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>'},
#  'developers': ['Petros Giannopoulos'],
#  'publishers': ['Petros Giannopoulos'],
#  'price_overview': {'currency': 'EUR',
#   'initial': 329,
#   'final': 329,
#   'discount_percent': 0,
#   'initial_formatted': '',
#   'final_formatted': '3,29€'},
#  'packages': [652873],
#  'package_groups': [{'name': 'default',
#    'title': 'Buy Split Tactics',
#    'description': '',
#    'selection_text': 'Select a purchase option',
#    'save_text': '',
#    'display_type': 0,
#    'is_recurring_subscription': 'false',
#    'subs': [{'packageid': 652873,
#      'percent_savings_text': ' ',
#      'percent_savings': 0,
#      'option_text': 'Split Tactics - 3,29€',
#      'option_description': '',
#      'can_get_free_license': '0',
#      'is_free_license': False,
#      'price_in_cents_with_discount': 329}]}],
#  'platforms': {'windows': True, 'mac': False, 'linux': False},
#  'categories': [{'id': 1, 'description': 'Multi-player'},
#   {'id': 49, 'description': 'PvP'},
#   {'id': 47, 'description': 'LAN PvP'}],
#  'genres': [{'id': '4', 'description': 'Casual'},
#   {'id': '2', 'description': 'Strategy'}],
#  'screenshots': [{'id': 0,
#    'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_2ac6e4af89e45c5287b12b35508ce3cf499c3720.600x338.jpg?t=1640856346',
#    'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_2ac6e4af89e45c5287b12b35508ce3cf499c3720.1920x1080.jpg?t=1640856346'},
#   {'id': 1,
#    'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_6c985c45c3f0644ba8dde0aae6ec0f0aa4f3f1f6.600x338.jpg?t=1640856346',
#    'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_6c985c45c3f0644ba8dde0aae6ec0f0aa4f3f1f6.1920x1080.jpg?t=1640856346'},
#   {'id': 2,
#    'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_d8a671ee8a55f317f659c47ac58869ddd1ac8dc4.600x338.jpg?t=1640856346',
#    'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_d8a671ee8a55f317f659c47ac58869ddd1ac8dc4.1920x1080.jpg?t=1640856346'},
#   {'id': 3,
#    'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_5aa285624af0ce1db0a8d570a93f62a659c6ce96.600x338.jpg?t=1640856346',
#    'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_5aa285624af0ce1db0a8d570a93f62a659c6ce96.1920x1080.jpg?t=1640856346'},
#   {'id': 4,
#    'path_thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_4d74265970f926f53d555b0f1b2b5bf695a7c42e.600x338.jpg?t=1640856346',
#    'path_full': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/ss_4d74265970f926f53d555b0f1b2b5bf695a7c42e.1920x1080.jpg?t=1640856346'}],
#  'movies': [{'id': 256859750,
#    'name': 'Gameplay Trailer',
#    'thumbnail': 'https://cdn.akamai.steamstatic.com/steam/apps/256859750/movie.293x165.jpg?t=1637020101',
#    'webm': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256859750/movie480_vp9.webm?t=1637020101',
#     'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256859750/movie_max_vp9.webm?t=1637020101'},
#    'mp4': {'480': 'http://cdn.akamai.steamstatic.com/steam/apps/256859750/movie480.mp4?t=1637020101',
#     'max': 'http://cdn.akamai.steamstatic.com/steam/apps/256859750/movie_max.mp4?t=1637020101'},
#    'highlight': True}],
#  'release_date': {'coming_soon': False, 'date': '30 Dec, 2021'},
#  'support_info': {'url': '', 'email': 'splittactics@gmail.com'},
#  'background': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/page_bg_generated_v6b.jpg?t=1640856346',
#  'background_raw': 'https://cdn.akamai.steamstatic.com/steam/apps/1815720/page.bg.jpg?t=1640856346',
#  'content_descriptors': {'ids': [], 'notes': None}}

# %%
## collecting the data with a for loop that checks if the response was a succes = True. and than takes the data attribute 
## with addition of try and excepts from michael 

details = {} 

counter = 1   
for i in app_ids: 
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": {i}}
    app_data = get_request(url, parameters=parameters)
    id = str(i)
    print("Processing data pertaining to Steam ID:"+id)
    response = app_data[id]
    succes = response["success"]
    if (succes): 
        data_json = response["data"]
        try:
            app_id = data_json["steam_appid"]
            name = data_json["name"]
            prod_type = data_json["type"]
            freemium = data_json["is_free"]
            price = data_json["price_overview"]["final_formatted"]
            discount = data_json["price_overview"]["discount_percent"]
            developer = data_json["developers"]
            publisher = data_json["publishers"]
            desc = data_json["detailed_description"]
            short_desc = data_json["short_description"]
            try:
                release_date = data_json["release_date"]["date"]
            except:
                release_date = "TBA"
            try:
                win = data_json["platforms"]["windows"]
            except:
                win = ""
            try:
                mac = data_json["platforms"]["mac"]
            except:
                mac = ""
            try:
                lin = data_json["platforms"]["linux"]
            except:
                lin = ""
            try:
                achievements = data_json["achievements"]["total"]
            except:
                achievements = "0"
            try:
                reviews = data_json["recommendations"]
            except:
                reviews = ""
            try:
                metacritic = data_json["metacritic"]
            except:
                metacritic = "not available"
            try:
                base_app = data_json["fullgame"]["appid"]
            except:
                base_app = "none"
            scrape_datetime = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
            details[app_id]=[name],[release_date],[freemium],[prod_type],[price],[discount],[developer],[publisher],[desc],[short_desc],[achievements],[win],[mac],[lin],[reviews],[metacritic],[base_app],[scrape_datetime]
        except:
            pass
        counter = counter + 1 
    if (counter > 10000):
        break

# %%
## collecting the data with a for loop that checks if the response was a succes = True. and than takes the data attribute 
dataframe = pd.DataFrame()
dataframe_categories = pd.DataFrame()
amount_app_ids = 1000
counter = 1   

for i in app_ids: 
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": {i}}
    app_data = get_request(url, parameters=parameters)
    id = str(i)
    print("Processing data pertaining to Steam ID:"+id)
    response = app_data[id]
    succes = response["success"]
    if (succes): 
        data_json = response["data"]
        steam_appid = data_json["steam_appid"]
        result = pd.json_normalize(data_json)
        dataframe = pd.concat([dataframe, result],ignore_index= True)
        try:
            categories = pd.json_normalize(data_json,record_path = ['categories'], meta = ["steam_appid"])
            dataframe_categories = pd.concat([dataframe_categories,categories],ignore_index= True)
        except:
            pass
        counter = counter + 1 
    if (counter > amount_app_ids):
        break
# Out:
# Your request is being processed.
# Processing data pertaining to Steam ID:216938
# Your request is being processed.
# Processing data pertaining to Steam ID:660010
# Your request is being processed.
# Processing data pertaining to Steam ID:660130
# Your request is being processed.
# Processing data pertaining to Steam ID:1118314
# Your request is being processed.
# Processing data pertaining to Steam ID:1275822
# Your request is being processed.
# Processing data pertaining to Steam ID:1343832
# Your request is being processed.
# Processing data pertaining to Steam ID:1828741
# Your request is being processed.
# Processing data pertaining to Steam ID:662172
# Your request is being processed.
# Processing data pertaining to Steam ID:1360782
# Your request is being processed.
# Processing data pertaining to Steam ID:1820332
# Your request is being processed.
# Processing data pertaining to Steam ID:1815690
# Your request is being processed.
# Processing data pertaining to Steam ID:1815720
# Your request is being processed.
# Processing data pertaining to Steam ID:1815730
# Your request is being processed.
# Processing data pertaining to Steam ID:1815740
# Your request is being processed.
# Processing data pertaining to Steam ID:1815750
# Your request is being processed.
# Processing data pertaining to Steam ID:1815770
# Your request is being processed.
# Processing data pertaining to Steam ID:1815800
# Your request is being processed.
# Processing data pertaining to Steam ID:1815820
# Your request is being processed.
# Processing data pertaining to Steam ID:1815860
# Your request is being processed.
# Processing data pertaining to Steam ID:1815870
# Your request is being processed.
# Processing data pertaining to Steam ID:1815880
# Your request is being processed.
# Processing data pertaining to Steam ID:1815890
# Your request is being processed.
# Processing data pertaining to Steam ID:1815931
# Your request is being processed.
# Processing data pertaining to Steam ID:1815932
# Your request is being processed.
# Processing data pertaining to Steam ID:1815933
# Your request is being processed.
# Processing data pertaining to Steam ID:1815950
# Your request is being processed.
# Processing data pertaining to Steam ID:1815970
# Your request is being processed.
# Processing data pertaining to Steam ID:1815990
# Your request is being processed.
# Processing data pertaining to Steam ID:1816010
# Your request is being processed.
# Processing data pertaining to Steam ID:1816020
# Your request is being processed.
# Processing data pertaining to Steam ID:1816050
# Your request is being processed.
# Processing data pertaining to Steam ID:1816060
# Your request is being processed.
# Processing data pertaining to Steam ID:1816080
# Your request is being processed.
# Processing data pertaining to Steam ID:1816100
# Your request is being processed.
# Processing data pertaining to Steam ID:1816120
# Your request is being processed.
# Processing data pertaining to Steam ID:1816130
# Your request is being processed.
# Processing data pertaining to Steam ID:1815250
# Your request is being processed.
# Processing data pertaining to Steam ID:1815260
# Your request is being processed.
# Processing data pertaining to Steam ID:1815270
# Your request is being processed.
# Processing data pertaining to Steam ID:1815300
# Your request is being processed.
# Processing data pertaining to Steam ID:1815310
# Your request is being processed.
# Processing data pertaining to Steam ID:1815340
# Your request is being processed.
# Processing data pertaining to Steam ID:1815350
# Your request is being processed.
# Processing data pertaining to Steam ID:1815370
# Your request is being processed.
# Processing data pertaining to Steam ID:1815400
# Your request is being processed.
# Processing data pertaining to Steam ID:1815430
# Your request is being processed.
# Processing data pertaining to Steam ID:1815440
# Your request is being processed.
# Processing data pertaining to Steam ID:1815450
# Your request is being processed.
# Processing data pertaining to Steam ID:1815470
# Your request is being processed.
# Processing data pertaining to Steam ID:1815490
# Your request is being processed.
# Processing data pertaining to Steam ID:1815500
# Your request is being processed.
# Processing data pertaining to Steam ID:1815550
# Your request is being processed.
# Processing data pertaining to Steam ID:1815580
# Your request is being processed.
# Processing data pertaining to Steam ID:1815590
# Your request is being processed.
# Processing data pertaining to Steam ID:1815600
# Your request is being processed.
# Processing data pertaining to Steam ID:1815610
# Your request is being processed.
# Processing data pertaining to Steam ID:1815620
# Your request is being processed.
# Processing data pertaining to Steam ID:1815650
# Your request is being processed.
# Processing data pertaining to Steam ID:1815660
# Your request is being processed.
# Processing data pertaining to Steam ID:1814730
# Your request is being processed.
# Processing data pertaining to Steam ID:1814740
# Your request is being processed.
# Processing data pertaining to Steam ID:1814750
# Your request is being processed.
# Processing data pertaining to Steam ID:1814760
# Your request is being processed.
# Processing data pertaining to Steam ID:1814770
# Your request is being processed.
# Processing data pertaining to Steam ID:1814780
# Your request is being processed.
# Processing data pertaining to Steam ID:1814800
# Your request is being processed.
# Processing data pertaining to Steam ID:1814840
# Your request is being processed.
# Processing data pertaining to Steam ID:1814850
# Your request is being processed.
# Processing data pertaining to Steam ID:1814860
# Your request is being processed.
# Processing data pertaining to Steam ID:1814870
# Your request is being processed.
# Processing data pertaining to Steam ID:1814880
# Your request is being processed.
# Processing data pertaining to Steam ID:1814920
# Your request is being processed.
# Processing data pertaining to Steam ID:1814930
# Your request is being processed.
# Processing data pertaining to Steam ID:1814940
# Your request is being processed.
# Processing data pertaining to Steam ID:1814950
# Your request is being processed.
# Processing data pertaining to Steam ID:1814960
# Your request is being processed.
# Processing data pertaining to Steam ID:1814970
# Your request is being processed.
# Processing data pertaining to Steam ID:1814990
# Your request is being processed.
# Processing data pertaining to Steam ID:1815000
# Your request is being processed.
# Processing data pertaining to Steam ID:1815010
# Your request is being processed.
# Processing data pertaining to Steam ID:1815020
# Your request is being processed.
# Processing data pertaining to Steam ID:1815030
# Your request is being processed.
# Processing data pertaining to Steam ID:1815040
# Your request is being processed.
# Processing data pertaining to Steam ID:1815050
# Your request is being processed.
# Processing data pertaining to Steam ID:1815060
# Your request is being processed.
# Processing data pertaining to Steam ID:1815080
# Your request is being processed.
# Processing data pertaining to Steam ID:1815090
# Your request is being processed.
# Processing data pertaining to Steam ID:1815110
# Your request is being processed.
# Processing data pertaining to Steam ID:1815130
# Your request is being processed.
# Processing data pertaining to Steam ID:1815140
# Your request is being processed.
# Processing data pertaining to Steam ID:1815160
# Your request is being processed.
# Processing data pertaining to Steam ID:1815170
# Your request is being processed.
# Processing data pertaining to Steam ID:1815190
# Your request is being processed.
# Processing data pertaining to Steam ID:1815200
# Your request is being processed.
# Processing data pertaining to Steam ID:1815210
# Your request is being processed.
# Processing data pertaining to Steam ID:1814220
# Your request is being processed.
# Processing data pertaining to Steam ID:1814230
# Your request is being processed.
# Processing data pertaining to Steam ID:1814240
# Your request is being processed.
# Processing data pertaining to Steam ID:1814250
# Your request is being processed.
# Processing data pertaining to Steam ID:1814260
# Your request is being processed.
# Processing data pertaining to Steam ID:1814270
# Your request is being processed.
# Processing data pertaining to Steam ID:1814300
# Your request is being processed.
# Processing data pertaining to Steam ID:1814310
# Your request is being processed.
# Processing data pertaining to Steam ID:1814340
# Your request is being processed.
# Processing data pertaining to Steam ID:1814370
# Your request is being processed.
# Processing data pertaining to Steam ID:1814380
# Your request is being processed.
# Processing data pertaining to Steam ID:1814390
# Your request is being processed.
# Processing data pertaining to Steam ID:1814400
# Your request is being processed.
# Processing data pertaining to Steam ID:1814430
# Your request is being processed.
# Processing data pertaining to Steam ID:1814450
# Your request is being processed.
# Processing data pertaining to Steam ID:1814480
# Your request is being processed.
# Processing data pertaining to Steam ID:1814490
# Your request is being processed.
# Processing data pertaining to Steam ID:1814500
# Your request is being processed.
# Processing data pertaining to Steam ID:1814510
# Your request is being processed.
# Processing data pertaining to Steam ID:1814520
# Your request is being processed.
# Processing data pertaining to Steam ID:1814540
# Your request is being processed.
# Processing data pertaining to Steam ID:1814550
# Your request is being processed.
# Processing data pertaining to Steam ID:1814560
# Your request is being processed.
# Processing data pertaining to Steam ID:1814570
# Your request is being processed.
# Processing data pertaining to Steam ID:1814590
# Your request is being processed.
# Processing data pertaining to Steam ID:1814600
# Your request is being processed.
# Processing data pertaining to Steam ID:1814610
# Your request is being processed.
# Processing data pertaining to Steam ID:1814630
# Your request is being processed.
# Processing data pertaining to Steam ID:1814640
# Your request is being processed.
# Processing data pertaining to Steam ID:1814650
# Your request is being processed.
# Processing data pertaining to Steam ID:1814660
# Your request is being processed.
# Processing data pertaining to Steam ID:1814670
# Your request is being processed.
# Processing data pertaining to Steam ID:1814680
# Your request is being processed.
# Processing data pertaining to Steam ID:1814690
# Your request is being processed.
# Processing data pertaining to Steam ID:1814700
# Your request is being processed.
# Processing data pertaining to Steam ID:1814710
# Your request is being processed.
# Processing data pertaining to Steam ID:1813740
# Your request is being processed.
# Processing data pertaining to Steam ID:1813750
# Your request is being processed.
# Processing data pertaining to Steam ID:1813780
# Your request is being processed.
# Processing data pertaining to Steam ID:1813790
# Your request is being processed.
# Processing data pertaining to Steam ID:1813810
# Your request is being processed.
# Processing data pertaining to Steam ID:1813820
# Your request is being processed.
# Processing data pertaining to Steam ID:1813830
# Your request is being processed.
# Processing data pertaining to Steam ID:1813840
# Your request is being processed.
# Processing data pertaining to Steam ID:1813850
# Your request is being processed.
# Processing data pertaining to Steam ID:1813860
# Your request is being processed.
# Processing data pertaining to Steam ID:1813880
# Your request is being processed.
# Processing data pertaining to Steam ID:1813890
# Your request is being processed.
# Processing data pertaining to Steam ID:1813930
# Your request is being processed.
# Processing data pertaining to Steam ID:1813940
# Your request is being processed.
# Processing data pertaining to Steam ID:1813960
# Your request is being processed.
# Processing data pertaining to Steam ID:1813990
# Your request is being processed.
# Processing data pertaining to Steam ID:1814000
# Your request is being processed.
# Processing data pertaining to Steam ID:1814010
# Your request is being processed.
# Processing data pertaining to Steam ID:1814030
# Your request is being processed.
# Processing data pertaining to Steam ID:1814040
# Your request is being processed.
# Processing data pertaining to Steam ID:1814060
# Your request is being processed.
# Processing data pertaining to Steam ID:1814090
# Your request is being processed.
# Processing data pertaining to Steam ID:1814100
# Your request is being processed.
# Processing data pertaining to Steam ID:1814110
# Your request is being processed.
# Processing data pertaining to Steam ID:1814120
# Your request is being processed.
# Processing data pertaining to Steam ID:1814150
# Your request is being processed.
# Processing data pertaining to Steam ID:1814160
# Your request is being processed.
# Processing data pertaining to Steam ID:1814170
# Your request is being processed.
# Processing data pertaining to Steam ID:1814180
# Your request is being processed.
# Processing data pertaining to Steam ID:1814200
# Your request is being processed.
# Processing data pertaining to Steam ID:1814210
# Your request is being processed.
# Processing data pertaining to Steam ID:1813230
# Your request is being processed.
# Processing data pertaining to Steam ID:1813240
# Your request is being processed.
# Processing data pertaining to Steam ID:1813260
# Your request is being processed.
# Processing data pertaining to Steam ID:1813300
# Your request is being processed.
# Processing data pertaining to Steam ID:1813310
# Your request is being processed.
# Processing data pertaining to Steam ID:1813320
# Your request is being processed.
# Processing data pertaining to Steam ID:1813330
# Your request is being processed.
# Processing data pertaining to Steam ID:1813340
# Your request is being processed.
# Processing data pertaining to Steam ID:1813350
# Your request is being processed.
# Processing data pertaining to Steam ID:1813360
# Your request is being processed.
# Processing data pertaining to Steam ID:1813370
# Your request is being processed.
# Processing data pertaining to Steam ID:1813390
# Your request is being processed.
# Processing data pertaining to Steam ID:1813400
# Your request is being processed.
# Processing data pertaining to Steam ID:1813410
# Your request is being processed.
# Processing data pertaining to Steam ID:1813450
# Your request is being processed.
# Processing data pertaining to Steam ID:1813460
# Your request is being processed.
# Processing data pertaining to Steam ID:1813480
# Your request is being processed.
# Processing data pertaining to Steam ID:1813510
# Your request is being processed.
# Processing data pertaining to Steam ID:1813520
# Your request is being processed.
# Processing data pertaining to Steam ID:1813540
# Your request is being processed.
# Processing data pertaining to Steam ID:1813550
# Your request is being processed.
# Processing data pertaining to Steam ID:1813560
# Your request is being processed.
# Processing data pertaining to Steam ID:1813570
# Your request is being processed.
# Processing data pertaining to Steam ID:1813590
# Your request is being processed.
# Processing data pertaining to Steam ID:1813620
# Your request is being processed.
# Processing data pertaining to Steam ID:1813650
# Your request is being processed.
# Processing data pertaining to Steam ID:1813670
# Your request is being processed.
# Processing data pertaining to Steam ID:1813690
# Your request is being processed.
# Processing data pertaining to Steam ID:1813710
# Your request is being processed.
# Processing data pertaining to Steam ID:1812820
# Your request is being processed.
# Processing data pertaining to Steam ID:1812840
# Your request is being processed.
# Processing data pertaining to Steam ID:1812850
# Your request is being processed.
# Processing data pertaining to Steam ID:1812860
# Your request is being processed.
# Processing data pertaining to Steam ID:1812870
# Your request is being processed.
# Processing data pertaining to Steam ID:1812880
# Your request is being processed.
# Processing data pertaining to Steam ID:1812881
# Your request is being processed.
# Processing data pertaining to Steam ID:1812882
# Your request is being processed.
# Processing data pertaining to Steam ID:1812883
# Your request is being processed.
# Processing data pertaining to Steam ID:1812884
# Your request is being processed.
# Processing data pertaining to Steam ID:1812885
# Your request is being processed.
# Processing data pertaining to Steam ID:1812886
# Your request is being processed.
# Processing data pertaining to Steam ID:1812887
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# Request unsuccessful, retrying in 5 seconds.
# Your request is being processed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1206412677.py in <module>
#       8     url = "http://store.steampowered.com/api/appdetails/"
#       9     parameters = {"appids": {i}}
# ---> 10     app_data = get_request(url, parameters=parameters)
#      11     id = str(i)
#      12     print("Processing data pertaining to Steam ID:"+id)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       9         print("Request unsuccessful, retrying in 5 seconds.")
#      10         time.sleep(5)
# ---> 11         return get_request(url, parameters)
#      12     time.sleep(1)
#
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/1059001487.py in get_request(url, parameters)
#       2 def get_request(url, parameters=None):
#       3     print("Your request is being processed.")
# ----> 4     response = requests.get(url=url, params=parameters)
#       5     if response:
#       6         return response.json()
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     392                 conn.request_chunked(method, url, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#     396         # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     237         if "user-agent" not in (six.ensure_str(k.lower()) for k in headers):
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#     241     def request_chunked(self, method, url, body=None, headers=None):
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1277                 encode_chunked=False):
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#    1281     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1323             # default charset of iso-8859-1.
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#    1327     def getresponse(self):
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1272         else:
#    1273             raise CannotSendHeader()
# -> 1274         self._send_output(message_body, encode_chunked=encode_chunked)
#    1275
#    1276     def request(self, method, url, body=None, headers={}, *,
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1032         msg = b"\r\n".join(self._buffer)
#    1033         del self._buffer[:]
# -> 1034         self.send(msg)
#    1035
#    1036         if message_body is not None:
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     972         if self.sock is None:
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#     976                 raise NotConnected()
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     203
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#     207
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71         )
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#      75         sock = None
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     952     # and socket type values to enum constants.
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#     956         addrlist.append((_intenum_converter(af, AddressFamily),
#
# KeyboardInterrupt:

# %%
#data_json = response["data"]
#result = pd.json_normalize(data_json)
#dataframe = pd.concat([dataframe, result],ignore_index= True)
categories = pd.json_normalize(data_json,record_path= ['categories'])
categories
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SERBA_~1\AppData\Local\Temp/ipykernel_201280/3587304184.py in <module>
#       2 #result = pd.json_normalize(data_json)
#       3 #dataframe = pd.concat([dataframe, result],ignore_index= True)
# ----> 4 categories = pd.json_normalize(data_json,record_path= ['categories'])
#       5 categories
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     502                 records.extend(recs)
#     503
# --> 504     _recursive_extract(data, record_path, {}, level=0)
#     505
#     506     result = DataFrame(records)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _recursive_extract(data, path, seen_meta, level)
#     475         else:
#     476             for obj in data:
# --> 477                 recs = _pull_records(obj, path[0])
#     478                 recs = [
#     479                     nested_to_record(r, sep=sep, max_level=max_level)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _pull_records(js, spec)
#     397         if has non iterable value.
#     398         """
# --> 399         result = _pull_field(js, spec)
#     400
#     401         # GH 31507 GH 30145, GH 26284 if result is not list, raise TypeError if not
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_normalize.py in _pull_field(js, spec)
#     388                 result = result[field]
#     389         else:
# --> 390             result = result[spec]
#     391         return result
#     392
#
# KeyError: 'categories'

# %%
#dataframe
#categories
dataframe.to_excel("D:\\1. Studie\\Master files\\dPrep-oDCM\\Git repo\\Steam-API\\steam-API\\data\\test_df.xlsx")
#categories = pd.json_normalize(data_json,record_path= ['categories'])
#pd.json_normalize(data_json)

# %%
### example to create a dictionary that checks if the id is already in the dictionary and then if not in dictionary get data 

"""
details = {}

for i in app_ids:
  id = str(i)
  if id not in details:
     // get data

     if(success):
       // put data in details
       details[id] = data

"""
# Out:
# '\ndetails = {}\n\nfor i in app_ids:\n  id = str(i)\n  if id not in details:\n     // get data\n\n     if(success):\n       // put data in details\n       details[id] = data\n\n'

# %%
#not relevant yet 
#trying to make a function out of it


"""
this is a comment 

def Get_tha_data(attributes, limit):
 
counter = 1   
for i in app_ids: 
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": {i}}
    app_data = get_request(url, parameters=parameters)       
    id = str(i)
    response = app_data[id]
    succes = response["success"]
    if (succes): 
        data_json = response["data"]
        print(data_json)
        counter = counter + 1 
    if (counter > limit):
        break           
"""

# %%
# Out:
#      type                                               name  steam_appid  \
# 0    game                                         Employee A      1815690
# 1    game                                      Split Tactics      1815720
# 2    game                                           BallRoll      1815730
# 3    game                                         The Healer      1815740
# 4    game               How to Take Off Your Mask Remastered      1815750
# ..    ...                                                ...          ...
# 185   dlc  Beat Saber: Lady Gaga, Colby O’Donis - 'Just D...      1812883
# 186   dlc                Beat Saber: Lady Gaga - 'Paparazzi'      1812884
# 187   dlc               Beat Saber: Lady Gaga - 'Poker Face'      1812885
# 188   dlc  Beat Saber: Lady Gaga, Ariana Grande - 'Rain O...      1812886
# 189   dlc              Beat Saber: Lady Gaga - 'Stupid Love'      1812887
#
#      required_age  is_free                               detailed_description  \
# 0               0    False  <img src="https://cdn.akamai.steamstatic.com/s...
# 1               0    False  Split Tactics is a casual game about choices. ...
# 2               0    False  Experience metaphorical descent into the land ...
# 3               0    False  <h2 class="bb_tag">THOUSANDS OF POSSIBILITIES!...
# 4               0    False  The cute fantasy visual novel, &quot;How to Ta...
# ..            ...      ...                                                ...
# 185             0    False  Get the track 'Just Dance (feat. Colby O’Donis...
# 186             0    False  Get the track 'Paparazzi' by Lady Gaga and sla...
# 187             0    False  Get the track 'Poker Face' by Lady Gaga and sl...
# 188             0    False  Get the track 'Rain On Me (with Ariana Grande)...
# 189             0    False  Get the track 'Stupid Love' by Lady Gaga and s...
#
#                                         about_the_game  \
# 0    <img src="https://cdn.akamai.steamstatic.com/s...
# 1    Split Tactics is a casual game about choices. ...
# 2    Experience metaphorical descent into the land ...
# 3    <h2 class="bb_tag">THOUSANDS OF POSSIBILITIES!...
# 4    The cute fantasy visual novel, &quot;How to Ta...
# ..                                                 ...
# 185  Get the track 'Just Dance (feat. Colby O’Donis...
# 186  Get the track 'Paparazzi' by Lady Gaga and sla...
# 187  Get the track 'Poker Face' by Lady Gaga and sl...
# 188  Get the track 'Rain On Me (with Ariana Grande)...
# 189  Get the track 'Stupid Love' by Lady Gaga and s...
#
#                                      short_description  \
# 0    A pixel art point-and-click adventure set in t...
# 1    A turn-based LAN multiplayer card game where p...
# 2    Experience metaphorical descent into the land ...
# 3    Can you get zero kills? It's a different exper...
# 4    The cute fantasy visual novel, &quot;How to Ta...
# ..                                                 ...
# 185  Get the track 'Just Dance' by Lady Gaga and sl...
# 186  Get the track 'Paparazzi' by Lady Gaga and sla...
# 187  Get the track 'Poker Face' by Lady Gaga and sl...
# 188  Get the track 'Rain On Me (with Ariana Grande)...
# 189  Get the track 'Stupid Love' by Lady Gaga and s...
#
#                                    supported_languages  \
# 0                                              English
# 1                                              English
# 2                                              English
# 3    English<strong>*</strong><br><strong>*</strong...
# 4    English, French, German, Japanese<strong>*</st...
# ..                                                 ...
# 185  English<strong>*</strong>, French<strong>*</st...
# 186  English<strong>*</strong>, French<strong>*</st...
# 187  English<strong>*</strong>, French<strong>*</st...
# 188  English<strong>*</strong>, French<strong>*</st...
# 189  English<strong>*</strong>, French<strong>*</st...
#
#                                           header_image  ...  \
# 0    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 1    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 2    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 3    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 4    https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# ..                                                 ...  ...
# 185  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 186  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 187  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 188  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
# 189  https://cdn.akamai.steamstatic.com/steam/apps/...  ...
#
#     achievements.total                           achievements.highlighted  \
# 0                  NaN                                                NaN
# 1                  NaN                                                NaN
# 2                  NaN                                                NaN
# 3                  NaN                                                NaN
# 4                 26.0  [{'name': 'All Achievements Unlocked!', 'path'...
# ..                 ...                                                ...
# 185                NaN                                                NaN
# 186                NaN                                                NaN
# 187                NaN                                                NaN
# 188                NaN                                                NaN
# 189                NaN                                                NaN
#
#     legal_notice fullgame.appid fullgame.name metacritic.score  \
# 0            NaN            NaN           NaN              NaN
# 1            NaN            NaN           NaN              NaN
# 2            NaN            NaN           NaN              NaN
# 3            NaN            NaN           NaN              NaN
# 4            NaN            NaN           NaN              NaN
# ..           ...            ...           ...              ...
# 185          NaN         620980    Beat Saber              NaN
# 186          NaN         620980    Beat Saber              NaN
# 187          NaN         620980    Beat Saber              NaN
# 188          NaN         620980    Beat Saber              NaN
# 189          NaN         620980    Beat Saber              NaN
#
#     pc_requirements reviews recommendations.total drm_notice
# 0               NaN     NaN                   NaN        NaN
# 1               NaN     NaN                   NaN        NaN
# 2               NaN     NaN                   NaN        NaN
# 3               NaN     NaN                   NaN        NaN
# 4               NaN     NaN                   NaN        NaN
# ..              ...     ...                   ...        ...
# 185             NaN     NaN                   NaN        NaN
# 186             NaN     NaN                   NaN        NaN
# 187             NaN     NaN                   NaN        NaN
# 188             NaN     NaN                   NaN        NaN
# 189             NaN     NaN                   NaN        NaN
#
# [190 rows x 57 columns]

# %%
# Out:
#      id           description steam_appid
# 0     2         Single-player     1815690
# 1     1          Multi-player     1815720
# 2    49                   PvP     1815720
# 3    47               LAN PvP     1815720
# 4     2         Single-player     1815730
# ..   ..                   ...         ...
# 483   1          Multi-player     1812887
# 484  49                   PvP     1812887
# 485  36            Online PvP     1812887
# 486  21  Downloadable Content     1812887
# 487  25    Steam Leaderboards     1812887
#
# [488 rows x 3 columns]
